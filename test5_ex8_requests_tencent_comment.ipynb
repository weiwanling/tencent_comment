# %% [markdown]
# # 腾讯视频评论爬虫实战(深度长评)
# - 深度长评的URL地址格式为：https://video.coral.qq.com/filmreviewr/c/upcomment/[视频id]?&reqnum=3&commentid=[评论id]
# - fildder
# - requests-re
# - 《新笑傲江湖》评论
# -  https://video.coral.qq.com/filmreviewr/c/upcomment/4baf2nzoljqyobl?&reqnum=3&commentid=0

# %%
import requests
import re
import random

def get_html(url,params):
    uapools=[
             'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36',
             'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:30.0) Gecko/20100101 Firefox/30.0',
             'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_2) AppleWebKit/537.75.14 (KHTML, like Gecko) Version/7.0.3 Safari/537.75.14'         
            ]
    
    thisua=random.choice(uapools)
    headers={"User-Agent":thisua}
    r=requests.get(url,headers=headers,params=params)
    r.raise_for_status()
    r.encoding=r.apparent_encoding
    return r.text
    

def parse_page(infolist,data):
    titlepat= '"title":"(.*?)"'
    commentpat='"abstract":"(.*?)"'
    lastpat='"last":"(.*?)"'
    
    titleall=re.compile(titlepat,re.S).findall(data)
    commentall=re.compile(commentpat,re.S).findall(data)
    next_cid=re.compile(lastpat).findall(data)[0]
    
    infolist.append([titleall[:len(commentall)],commentall])
    
    return next_cid

def print_comment_list(infolist):
    j=0
    for page in infolist:
        print('第'+str(j+1)+'页\n')
        titleall=page[0]
        commentall=page[1]
        for i in range(0,len(commentall)):
            print('='*30)
            print('评论标题：'+eval('u'+"'"+titleall[i]+"'")+'\n')
            print('评论内容：'+eval('u'+"'"+commentall[i]+"'")+'\n')
        j+=1
    
    
def save_to_txt(infolist,path):
    fw=open(path,'w+',encoding='utf-8')
    j=0
    for page in infolist:
        fw.write('第'+str(j+1)+'页\n')
        titleall=page[0]
        commentall=page[1]
        for i in range(0,len(commentall)):
            fw.write('='*30+'\n')
            fw.write('评论标题：'+eval('u'+"'"+titleall[i]+"'")+'\n')
            fw.write('评论内容是：'+eval('u'+"'"+commentall[i]+"'")+'\n')
        j+=1
    fw.close()

# %%
def main():
    infolist=[]       #page_nnum x 2(titleall,commentall) x req_num
    vid= '4baf2nzoljqyobl';  next_cid='0'; page_num=2
    
    for i in range(page_num):
        url='https://video.coral.qq.com/filmreviewr/c/upcomment/'+vid+'?'
        params={'commentid': next_cid,'reqnum': '3'}
        html=get_html(url,params)
        next_cid=parse_page(infolist,html)
    
    print_comment_list(infolist)
    save_to_txt(infolist,'./tencent_comment/xajh_cp.txt')
        
main()
# Out:
# 第1页
#
# ==============================
# 评论标题：正邪两端
#
# 评论内容：细品金庸先生的《笑傲江湖》，每个人物都鲜活动人，亦正亦邪，所谓的名门正派，道貌岸然，谦谦君子，虚伪奸邪；而众人口中的魔道邪教，却爱憎分明，快意恩仇，纵横江湖，畅快坦荡。到底谁才是正，哪个才是邪？人本就是个矛盾的集合体，优劣同存，正邪交融，很难用简单的好坏、黑白来区分，想来灰色的还是众数。人无完人，至臻只能追求，无人企及，本就无可厚非，可偏偏总有给自己盖个好人的戳，再按所谓的标准划分出来的妖孽异类。有了名门正派的印记，便可...
#
# ==============================
# 评论标题：有一种爱叫 东方不败。如果喜欢的话就点个赞
#
# 评论内容：陪你喝酒陪你练剑给你跳舞给你唱歌给你送饭给你疗伤你被欺负给你报仇、为照顾你彻夜未眠以为你有危险被你师傅追杀 以为你被害受众人围攻、以为你支持自己的敌人宁愿放弃权位、以为你会自尽所以把心脏掏出给情敌、对令狐冲而言懵懂是岳灵姗刻骨是东方不败一生是任盈盈、对东方不败而言，懵懂是令狐冲，刻骨是令狐冲，一生是令狐冲。”“她的心坚硬如铁，却在看到他的一瞬化为湖水，宏图霸业怎敌守在他身边多看他一眼？于是她背弃了她的骄傲她的理想，来到他...
#
# ==============================
# 评论标题：《学习乔恩版东方不败的肆意江湖》
#
# 评论内容：风清扬说“宏图霸业和红尘爱恨是人世中的两种束缚”。乔恩版东方不败一开始只追逐名利，束缚于雄图霸业。后来遇上了爱情，便倾尽所有，付出自己全部的爱，甚至用生命去维护这段爱情。虽然最后没有与自己心爱的男人在一起，但只要自己心爱的人开心，自己也就开心。东方最终放下了，自在了，“宏图霸业”、“红尘爱恨”，人世间的两种束缚，她都放下了。本剧最后的一个镜头：东方在湖底开心的笑了。东方不败，真正的做到了笑傲江湖。学习东方姑娘的境界，爱情...
#
# 第2页
#
# ==============================
# 评论标题：真正笑傲江湖的东方不败
#
# 评论内容：从小就是金庸武侠小说迷，《笑傲江湖》各个电视剧版本反反复复一共看过不下10次。本来对于正版的《笑傲江湖》不太感兴趣，所以一直没想过观看，上周偶然机会看了并一发不可收拾，五天内连续看了2遍电视版和1遍文字版，原因很简单：跟大家一样，对于东方不败的结局感到非常不解、遗憾，甚至忿忿不平。为什么冲东恋最终没能修成正果？看着东方与令狐冲“悬崖最后诀别”以及“尸沉冰湖”两段剧情的时候，眼泪都冲出眼眶了。于是，我带着不解与遗憾一遍一遍...
#
# ==============================
# 评论标题：新笑傲后期的令狐冲配不上东方不败的爱
#
# 评论内容：首先，要先分析下东方为什么会爱上令狐冲。令狐冲可以为了救了一个陌生人，而赔上自己的性命也在所不惜，令狐冲洒脱不羁，功名利禄、世俗观念无法给他带来束缚，他，就是这样一个乐观自由、重情重义的阳光大男孩。当一直困身于名利场当中，习惯尔虞我诈的东方不败遇上了令狐冲这一缕阳光，她开始审视自己的价值观，她质疑自己一直以来是否得到了快乐，是否感受过爱，此时，她久未出现波澜的内心，泛起了一阵涟漪。遇见令狐冲，她一见钟情了。然而，这只是前...
#
# ==============================
# 评论标题：东方最后选择埋葬于冰湖的原因
#
# 评论内容：山洞表白”一幕，东方姑娘终于忍不住掏心倾诉“自从我遇见到你的那天开始，我的心就像跌进了一个深深的湖水，推不开，躲不掉，心里只想往你身上靠”。湖水是代表东方姑娘对令狐冲的浓浓爱意，可是湖水冰冷无比，冷得让人极度难受，但东方最后还是选择埋葬于冰湖，不想推、不想躲，凝固在湖底深处，对令狐矢志不渝的爱下去，“世间多少痴儿女，爱到深处无怨尤”。

# %% [markdown]
# # 腾讯视频评论爬虫实战(短评)
# - 全部短评评论的URL地址格式为：https://video.coral.qq.com/varticle/[视频编号]/comment/v2?&orinum=[返回评论个数]&cursor=[评论标号]"
# - fildder
# - urllib-re
# - 《新笑傲江湖》评论
# -  https://video.coral.qq.com/varticle/1001103527/comment/v2?&orinum=12&cursor=0

# %%
import requests
import re
import random

def get_html(url,params):
    uapools=[
             'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36',
             'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:30.0) Gecko/20100101 Firefox/30.0',
             'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_2) AppleWebKit/537.75.14 (KHTML, like Gecko) Version/7.0.3 Safari/537.75.14'         
            ]
    
    thisua=random.choice(uapools)
    headers={"User-Agent":thisua}
    r=requests.get(url,headers=headers,params=params)
    r.raise_for_status()
    r.encoding=r.apparent_encoding
    r.encoding='utf-8'       # 不加此句出现乱码
    return r.text
    

def parse_page(infolist,data):
    commentpat='"content":"(.*?)"'
    lastpat='"last":"(.*?)"'
    
    commentall=re.compile(commentpat,re.S).findall(data)
    next_cid=re.compile(lastpat).findall(data)[0]
    
    infolist.append(commentall)
    
    return next_cid

def print_comment_list(infolist):
    j=0
    for page in infolist:
        print('第'+str(j+1)+'页\n')
        commentall=page
        for i in range(0,len(commentall)):
            print('评论内容：'+commentall[i]+'\n')
        j+=1
    
    
def save_to_txt(infolist,path):
    fw=open(path,'w+',encoding='utf-8')
    j=0
    for page in infolist:
        fw.write('第'+str(j+1)+'页\n')
        commentall=page
        for i in range(0,len(commentall)):
            fw.write('评论内容：'+commentall[i]+'\n')
        j+=1
    fw.close()

# %%
def main():
    infolist=[]
    vid='1001103527';  cid = "0"; page_num=2
    url = 'https://video.coral.qq.com/varticle/'+vid+'/comment/v2'
    
    for i in range(page_num):
        params={'orinum':'10','cursor':cid}
        html=get_html(url,params)
        cid=parse_page(infolist,html)
    
    print_comment_list(infolist)
    save_to_txt(infolist,'./tencent_comment/xajh_dp.txt')
    
main()
# Out:
# 第1页
#
# 评论内容：东方不败开始怎么不换个配音啊
#
# 评论内容：哈哈，这个版本高级啊，居然念得是:a弥陀福！
#
# 评论内容：2019年11月10日 游来
#
# 评论内容：还是这个版本的牛逼，其他的看都不想看
#
# 评论内容：我是来看东方不败的
#
# 评论内容：任盈盈那个嘴，是死亡芭比粉，这太尬尴了！
#
# 评论内容：来刷霍建华的剧，好看
#
# 评论内容：我喜欢任盈盈，人又好看，颜值又高。
#
# 评论内容：还是陈乔恩，演待好看
#
# 评论内容：666
#
# 第2页
#
# 评论内容：呵呵，666666666
#
# 评论内容：小师妹是他的初恋东方是他的暧昧莹莹是他的女友哈哈哈 男人就是走马观花见一个忘一个呢 这部演的女主角很恶心 不讨喜不说长的太难看了特别嘴巴
#
# 评论内容：本剧令狐爱上的是弹琴得婆婆 所以
#
# 评论内容：太监斗殴
#
# 评论内容：刚刚从抖音来的。哈哈哈啊哈哈
#
# 评论内容：2019.10.1重温笑傲
#
# 评论内容：袁姗姗好漂亮，演技又好，为什么有人不喜欢她
#
# 评论内容：特别喜欢这个东方不败，简直完美
#
# 评论内容：陈乔恩好帅，不亏是我的女神啊
#
# 评论内容：五岳名山到底是那几个哦？
